# %% [markdown]
# # import our AutoDP

# %%
# import
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import autodatapre as AutoDP
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 warnings.filterwarnings("ignore")
#       4 import pandas as pd
# ----> 5 import autodatapre as AutoDP
#       6 import os
#
# ModuleNotFoundError: No module named 'autodatapre'

# %%
# !pip install autodatapre
# Out:
# Looking in indexes: http://pypi.org/simple/
# WARNING: The repository located at pypi.org is not a trusted or secure host and is being ignored. If this repository is available via HTTPS we recommend you use HTTPS instead, otherwise you may silence this warning and allow it anyway with '--trusted-host pypi.org'.
# ERROR: Could not find a version that satisfies the requirement autodatapre (from versions: none)
# ERROR: No matching distribution found for autodatapre
# WARNING: The repository located at pypi.org is not a trusted or secure host and is being ignored. If this repository is available via HTTPS we recommend you use HTTPS instead, otherwise you may silence this warning and allow it anyway with '--trusted-host pypi.org'.

# %% [markdown]
# # Classification Task with a Runtime of 10s

# %% [markdown]
# ## Step 1. Task Information Import

# %%
datasetName = 'datasets/42493.csv'
datasetTarget = 'Delay'
runTime=10
df = pd.read_csv(datasetName, sep=',', encoding='ISO-8859-1')
df
# Out:
#       Airline  Flight AirportFrom AirportTo  DayOfWeek    Time  Length  Delay
# 0          OO    4492         GJT       SLC          6   785.0    56.0      0
# 1          EV    5364         MGM       MEM          6   375.0    76.0      0
# 2          FL    1016         BOS       MCO          7   703.0   205.0      0
# 3          F9     231         BNA       DEN          5   880.0   173.0      0
# 4          AS     662         SEA       DFW          5   730.0   230.0      0
# ...       ...     ...         ...       ...        ...     ...     ...    ...
# 26964      AA     374         ORD       LGA          4   725.0   125.0      0
# 26965      WN    1294         LAX       PHX          4   965.0    80.0      1
# 26966      FL    1400         ROC       MCO          7   797.0   168.0      0
# 26967      DL    1138         STL       ATL          7  1135.0    99.0      1
# 26968      WN    1019         SFO       LAX          2   385.0    75.0      0
#
# [26969 rows x 8 columns]

# %% [markdown]
# ## Step 2. Pipeline Generation

# %%
detailResult,preparedDataset=AutoDP.Classifier(df,datasetName,datasetTarget,runTime)

# %% [markdown]
# ## Step 3. Statistics and Analysis

# %%
AutoDP.EnhancedFunction(df,preparedDataset,detailResult,taskType="CLA")

# %% [markdown]
# ## Step 4. Store the processed dataset locally

# %%
AutoDP.store(datasetName,preparedDataset)
# Out:
# The dataset processed by AutoDP is saved to: datasets\42493_Prepared.csv

# %% [markdown]
# # Regression Task with Convergence Runtime

# %% [markdown]
# ## Step 1. Task Information Import

# %%
datasetName = 'datasets/573.csv'
datasetTarget = 'usr'
df = pd.read_csv(datasetName, sep=',', encoding='ISO-8859-1')
df
# Out:
#       lread  lwrite   scall  sread  swrite   fork   exec     rchar     wchar  \
# 0       6.0     2.0  1036.0  103.0   114.0   1.00   1.00  172076.0  355965.0
# 1       1.0     0.0  2165.0  205.0   101.0   0.40   1.20   43107.0   44139.0
# 2      62.0    77.0  3806.0  258.0   166.0   1.40   1.40  492142.0  268706.0
# 3       5.0     0.0  4721.0  256.0   177.0   0.99   2.58  524787.0  174964.0
# 4      42.0    55.0  3949.0  249.0   244.0   2.60   4.60  197289.0  529200.0
# ...     ...     ...     ...    ...     ...    ...    ...       ...       ...
# 8187   74.0    49.0  2688.0  176.0   103.0  11.00  32.20   57714.0   38484.0
# 8188   29.0    40.0  1906.0  118.0    90.0   0.80   2.00    8175.0   27313.0
# 8189    3.0     0.0   926.0   90.0    67.0   0.60   1.00    5411.0   19322.0
# 8190    4.0     0.0   418.0   30.0    29.0   0.80   1.00    3959.0   10679.0
# 8191    5.0     0.0  1888.0  248.0   215.0   6.20   1.80  216420.0   39346.0
#
# ...

# %% [markdown]
# ## Step 2. Pipeline Generation

# %%
detailResult,preparedDataset=AutoDP.Regressor(df,datasetName,datasetTarget)
# Out:
# <div style='font-size: 20px; font-family: Times New Roman;'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Run Time:&nbsp; 24.21s</div>

# %% [markdown]
# ## Step 3. Statistics and Analysis

# %%
AutoDP.EnhancedFunction(df,preparedDataset,detailResult,taskType="REG")

# %% [markdown]
# ## Step 4. Store the processed dataset locally

# %%
AutoDP.store(datasetName,preparedDataset)
# Out:
# The dataset processed by AutoDP is saved to: datasets\573_Prepared.csv
